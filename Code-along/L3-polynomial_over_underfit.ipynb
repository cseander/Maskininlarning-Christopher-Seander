# %% [markdown]
# ## Polynomial regression, underfitting, overfitting

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
samples = 100
# colon matrix
X = np.random.uniform(-3, 3, (samples, 1))
f = lambda x: x**2 + .5*x + 3

y = f(X) + np.random.randn(samples, 1)

plt.plot(X, y, '.')

x = np.linspace(-3, 3)
plt.plot(x, f(x))
plt.title("Simulated data")
# Out:
# Text(0.5, 1.0, 'Simulated data')

# %% [markdown]
# ## Polynomial regression

# %%
from sklearn.preprocessing import PolynomialFeatures

polynomial_features = PolynomialFeatures(degree = 2, include_bias=False)
poly_x = polynomial_features.fit_transform(X)
poly_x[:3]
# Out:
# array([[-1.96526267,  3.86225738],
#        [ 2.12602289,  4.51997332],
#        [-2.82996238,  8.00868705]])

# %%
from sklearn.linear_model import LinearRegression
model = LinearRegression()
model.fit(poly_x, y)
model.coef_
# Out:
# array([[0.48149557, 0.97376843]])

# %%
x = np.linspace(-3, 3, samples).reshape(samples, 1)
x_poly_features = polynomial_features.transform(x)
y_pred = model.predict(x_poly_features)

# %%
plt.plot(x, y_pred)
